# %% [markdown]
# ## BIG EXPRESS EDA v1 - 4/5/2022
# ### ROLL ON EIGHTEEN WHEELERS

# %%
# IMPORT LIBRARIES
import numpy as np
import pandas as pd
# import sqlite3    # ONLY IMPORT THIS ONCE FOR A SET OF FILES
from tqdm.notebook import tqdm

# %%
jfaults = pd.read_csv('../data/J1939Faults.csv', 
                      dtype={'EquipmentID': str})

# %%
jfaults.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  faultValue  \
# 0  unknown          0   111   17    True                      2         NaN
# 1  unknown         11   629   12    True                    127         NaN
# 2  unknown         11  1807    2   False                    127         NaN
# 3  unknown         11  1807    2    True                    127         NaN
# 4    VOLVO          0  4364   17   False                      2         NaN
#
#   EquipmentID  MCTNumber   Latitude  Longitude        LocationTimeStamp
# 0        1439  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1        1439  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2        1369  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3        1369  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4        1674  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000

# %%
jfaults.shape
# Out:
# (1187335, 20)

# %%
jfaults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187335 entries, 0 to 1187334
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   RecordID               1187335 non-null  int64
#  1   ESS_Id                 1187335 non-null  int64
#  2   EventTimeStamp         1187335 non-null  object
#  3   eventDescription       1126490 non-null  object
#  4   actionDescription      0 non-null        float64
#  5   ecuSoftwareVersion     891285 non-null   object
#  6   ecuSerialNumber        844318 non-null   object
#  7   ecuModel               1122577 non-null  object
#  8   ecuMake                1122577 non-null  object
#  9   ecuSource              1187335 non-null  int64
#  10  spn                    1187335 non-null  int64
#  11  fmi                    1187335 non-null  int64
#  12  active                 1187335 non-null  bool
#  13  activeTransitionCount  1187335 non-null  int64
#  14  faultValue             0 non-null        float64
#  15  EquipmentID            1187335 non-null  object
#  16  MCTNumber              1187335 non-null  int64
#  17  Latitude               1187335 non-null  float64
#  18  Longitude              1187335 non-null  float64
#  19  LocationTimeStamp      1187335 non-null  object
# dtypes: bool(1), float64(4), int64(7), object(8)
# memory usage: 173.2+ MB

# %%
jfaults['EquipmentID'] = jfaults['EquipmentID']\
                            .map(lambda x: x.lstrip('R')\
                                 .rstrip('aAbBcC'))

# %%
jfaults['EquipmentID'] = pd.to_numeric(jfaults['EquipmentID'])

# %%
# np.where(len(jfaults['EquipmentID']) > 5)
jfaults[jfaults['EquipmentID'] >= 100000]
# Out:
#          RecordID     ESS_Id           EventTimeStamp  \
# 7069         7070    1157485  2015-03-03 09:18:42.000
# 7070         7071    1157507  2015-03-03 09:19:43.000
# 59121       61191    2545755  2015-05-21 08:16:17.000
# 59587       61657    2553312  2015-05-21 13:27:44.000
# 60728       62798    2570947  2015-05-22 10:44:37.000
# ...           ...        ...                      ...
# 1151754   1208978  107277367  2019-10-23 09:48:05.000
# 1151759   1208983  107278317  2019-10-23 09:53:52.000
# 1151763   1208987  107278881  2019-10-23 09:57:38.000
# 1176114   1236255  118205869  2020-01-23 16:53:26.000
# 1184585   1245709  122439490  2020-02-25 13:09:36.000
#
#                                           eventDescription  actionDescription  \
# 7069                                                   NaN                NaN
# 7070                    Abnormal Update Rate Tire Location                NaN
# 59121                                                  NaN                NaN
# 59587                                                  NaN                NaN
# 60728    High (Severity Medium) Aftertreatment 1 Intake...                NaN
# ...                                                    ...                ...
# 1151754   Abnormal Update Rate Engine Total Idle Fuel Used                NaN
# 1151759                                                NaN                NaN
# 1151763                                                NaN                NaN
# 1176114         Low (Severity Medium) Engine Coolant Level                NaN
# 1184585           Incorrect Data Engine Crankcase Pressure                NaN
#
#                                         ecuSoftwareVersion ecuSerialNumber  \
# 7069                                               unknown         unknown
# 7070                                               unknown         unknown
# 59121      04993120*00027785*040213150018*07700044*I0*BBZ*        79464671
# 59587      04993120*00027785*040213150018*07700044*I0*BBZ*        79464671
# 60728      04993120*00027785*040213150018*07700044*I0*BBZ*        79464671
# ...                                                    ...             ...
# 1151754                                                NaN             NaN
# 1151759  5516018*202.56.0*5516502*E003.e003*5539540*25....        Z0082771
# 1151763  5516018*202.56.0*5516502*E003.e003*5539540*25....        Z0082771
# 1176114    04384413*22380869*082218154102*60701732*G1*BGT*        80156146
# 1184585    04384413*22115065*090617144354*60701715*G1*BGT*        80034544
#
#                   ecuModel  ecuMake  ecuSource   spn  fmi  active  \
# 7069               unknown  unknown         11     0    0    True
# 7070               unknown  unknown         49   929    9    True
# 59121    6X1u10D1500000000    CMMNS          0  4364   18    True
# 59587    6X1u10D1500000000    CMMNS          0  4364   18    True
# 60728    6X1u10D1500000000    CMMNS          0  3216   16    True
# ...                    ...      ...        ...   ...  ...     ...
# 1151754                NaN      NaN         49   236    9   False
# 1151759        EEO-xxF112C    EATON          3  8484    9    True
# 1151763        EEO-xxF112C    EATON          3  8484    9   False
# 1176114  6X1u17D1500000000    CMMNS          0   111   18   False
# 1184585  6X1u17D1500000000    CMMNS          0   101    2   False
#
#          activeTransitionCount  faultValue  EquipmentID  MCTNumber   Latitude  \
# 7069                       127         NaN    105438416  105438416  35.588148
# 7070                       126         NaN    105438416  105438416  35.588148
# 59121                        1         NaN    105393153  105393153  33.340046
# 59587                        1         NaN    105393153  105393153  33.339675
# 60728                        1         NaN    105393153  105393153  33.897731
# ...                        ...         ...          ...        ...        ...
# 1151754                      1         NaN    105455678  105455678  35.588379
# 1151759                      1         NaN    105455678  105455678  35.588379
# 1151763                      1         NaN    105455678  105455678  35.588379
# 1176114                      4         NaN    105411909  105411909  36.135000
# 1184585                      1         NaN    105393087  105393087  36.066157
#
#          Longitude        LocationTimeStamp
# 7069    -86.444027  2015-02-24 14:11:01.000
# 7070    -86.444027  2015-02-24 14:11:01.000
# 59121   -87.019212  2015-05-21 08:19:05.000
# 59587   -86.925833  2015-05-21 13:27:40.000
# 60728   -87.624629  2015-05-22 10:44:33.000
# ...            ...                      ...
# 1151754 -86.443842  2019-10-23 09:48:00.000
# 1151759 -86.443842  2019-10-23 09:54:29.000
# 1151763 -86.443842  2019-10-23 09:57:33.000
# 1176114 -83.290138  2020-01-23 17:00:23.000
# 1184585 -86.434768  2020-02-21 04:28:01.000
#
# [2169 rows x 20 columns]

# %%
jfaults = jfaults[jfaults['EquipmentID'] < 100000]

# %%
jfaults.drop('actionDescription', 
             axis=1, 
             inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
jfaults.drop('faultValue', 
             axis=1, 
             inplace=True)

# %%
jfaults.head()
# Out:
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  \
# 0  Low (Severity Low) Engine Coolant Level
# 1                                      NaN
# 2      Incorrect Data Steering Wheel Angle
# 3      Incorrect Data Steering Wheel Angle
# 4                                      NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  EquipmentID  \
# 0  unknown          0   111   17    True                      2         1439
# 1  unknown         11   629   12    True                    127         1439
# 2  unknown         11  1807    2   False                    127         1369
# 3  unknown         11  1807    2    True                    127         1369
# 4    VOLVO          0  4364   17   False                      2         1674
#
#    MCTNumber   Latitude  Longitude        LocationTimeStamp
# 0  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000

# %%
# TO DO

jfaults_db = sqlite3.connect('../data/J1939Faults.csv')

for chunk in tqdm(pd.read_csv('../data/J1939Faults.csv', 
                              chunksize = 10000)):
    # chunk.columns = [x.lower().replace(' ', '_') for x in chunk.columns]   
    chunk.to_sql('big_g', db, 
                 if_exists = 'append', 
                 index = False)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1724         try:
# -> 1725             cur.execute(*args, **kwargs)
#    1726             return cur
#
# DatabaseError: file is not a database
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-44-148b258c8e8a> in <module>
#       6                               chunksize = 10000)):
#       7     # chunk.columns = [x.lower().replace(' ', '_') for x in chunk.columns]
# ----> 8     chunk.to_sql('big_g', db,
#       9                  if_exists = 'append',
#      10                  index = False)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1869             dtype=dtype,
#    1870         )
# -> 1871         table.create()
#    1872         table.insert(chunksize, method)
#    1873
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     734
#     735     def create(self):
# --> 736         if self.exists():
#     737             if self.if_exists == "fail":
#     738                 raise ValueError(f"Table '{self.name}' already exists.")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in exists(self)
#     718
#     719     def exists(self):
# --> 720         return self.pd_sql.has_table(self.name, self.schema)
#     721
#     722     def sql_schema(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in has_table(self, name, schema)
#    1880         query = f"SELECT name FROM sqlite_master WHERE type='table' AND name={wld};"
#    1881
# -> 1882         return len(self.execute(query, [name]).fetchall()) > 0
#    1883
#    1884     def get_table(self, table_name, schema=None):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1735
#    1736             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1737             raise ex from exc
#    1738
#    1739     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT name FROM sqlite_master WHERE type='table' AND name=?;': file is not a database

# %%
# db.execute('CREATE INDEX average_day_wait ON jfaults(...))')

# %%
# TO DO
jfaults_query = "SELECT * FROM jfaults WHERE EquipmentID <= 5 LIMIT 100"

jfaults_sqlite = pd.read_sql(jfaults_query, jfaults_db)

# jfaults_db.close()
